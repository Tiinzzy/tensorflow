# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tempfile import TemporaryFile
# Out:
# 2023-09-26 19:08:00.487266: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-26 19:08:00.652682: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-26 19:08:00.653438: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-26 19:08:01.911461: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
num_threads = 5
os.environ["OMP_NUM_THREADS"] = "5"
os.environ["TF_NUM_INTRAOP_THREADS"] = "5"
os.environ["TF_NUM_INTEROP_THREADS"] = "5"
tf.config.threading.set_inter_op_parallelism_threads(num_threads)
tf.config.threading.set_intra_op_parallelism_threads(num_threads)
tf.config.set_soft_device_placement(True)

# %%
(train_X, train_Y), (test_X, test_Y) = fashion_mnist.load_data()

train_X = train_X.reshape((len(train_X), 28, 28, 1))
test_X = test_X.reshape((len(test_X), 28, 28, 1))    
train_X = tf.image.grayscale_to_rgb(tf.convert_to_tensor(train_X), name=None)
test_X = tf.image.grayscale_to_rgb(tf.convert_to_tensor(test_X), name=None)    


train_Y_one_hot = to_categorical(train_Y)
test_Y_one_hot = to_categorical(test_Y)

DEV_SIZE = 8000

test_X = test_X[:DEV_SIZE]
train_X = train_X[:DEV_SIZE]

test_Y = test_Y_one_hot[:DEV_SIZE]
train_Y = train_Y_one_hot[:DEV_SIZE]

# %%
test_X.shape, train_X.shape, test_Y.shape, train_Y.shape
# Out:
# (TensorShape([8000, 28, 28, 3]),
#  TensorShape([8000, 28, 28, 3]),
#  (8000, 10),
#  (8000, 10))

# %%
IMG_SIZE = 36
IMG_SHAPE = (IMG_SIZE, IMG_SIZE, 3)

def plot_one(img):
    plt.figure()
    plt.imshow(img)

def fix_one(img):
    img = tf.cast(img, tf.float32)
    img = (img/127.5) - 1
    img = tf.image.resize(img, (IMG_SIZE, IMG_SIZE))
    return img

def fix_all(x):   
    new_x = []
    for i in range(len(x)):
        new_x.append(fix_one(x[i]))
    return np.array(new_x)
    
train_X = fix_all(train_X)
test_X = fix_all(test_X)

# %%
test_X.shape, train_X.shape, test_Y.shape, train_Y.shape
# Out:
# ((8000, 36, 36, 3), (8000, 36, 36, 3), (8000, 10), (8000, 10))

# %%
np.max(train_X[0]), np.min(train_X[0])
# Out:
# (1.0, -1.0)

# %%
test_Y_one_hot.shape
# Out:
# (10000, 10)

# %%
train_size = len(train_X) * 9 // 10

valid_X = train_X[train_size:]
valid_label = train_Y[train_size:]

train_X = train_X[:train_size]
train_label = train_Y[:train_size]

# %%
train_X.shape, valid_X.shape, train_label.shape, valid_label.shape
# Out:
# ((7200, 36, 36, 3), (800, 36, 36, 3), (7200, 10), (800, 10))

# %%
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE, include_top=False, weights='imagenet')
base_model.trainable = False
base_model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 36, 36, 3)]          0         []
#
#  Conv1 (Conv2D)              (None, 18, 18, 32)           864       ['input_3[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 18, 18, 32)           128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 18, 18, 32)           0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 18, 18, 32)           288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 18, 18, 32)           128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 18, 18, 32)           0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 18, 18, 16)           512       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 18, 18, 16)           64        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 18, 18, 96)           1536      ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 18, 18, 96)           384       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 18, 18, 96)           0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 19, 19, 96)           0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 9, 9, 96)             864       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 9, 9, 96)             384       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 9, 9, 96)             0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 9, 9, 24)             2304      ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 9, 9, 24)             96        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 9, 9, 144)            3456      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 9, 9, 144)            576       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 9, 9, 144)            0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 9, 9, 144)            1296      ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 9, 9, 144)            576       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 9, 9, 144)            0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 9, 9, 24)             3456      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 9, 9, 24)             96        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 9, 9, 24)             0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 9, 9, 144)            3456      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 9, 9, 144)            576       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 9, 9, 144)            0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 11, 11, 144)          0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 5, 5, 144)            1296      ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 5, 5, 144)            576       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 5, 5, 144)            0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 5, 5, 32)             4608      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 5, 5, 32)             128       ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 5, 5, 192)            6144      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 5, 5, 192)            768       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 5, 5, 192)            0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 5, 5, 192)            1728      ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 5, 5, 192)            768       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 5, 5, 192)            0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 5, 5, 32)             6144      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 5, 5, 32)             128       ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 5, 5, 32)             0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 5, 5, 192)            6144      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 5, 5, 192)            768       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 5, 5, 192)            0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 5, 5, 192)            1728      ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 5, 5, 192)            768       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 5, 5, 192)            0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 5, 5, 32)             6144      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 5, 5, 32)             128       ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 5, 5, 32)             0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 5, 5, 192)            6144      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 5, 5, 192)            768       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 5, 5, 192)            0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 7, 7, 192)            0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 3, 3, 192)            1728      ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 3, 3, 192)            768       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 3, 3, 192)            0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 3, 3, 64)             12288     ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 3, 3, 64)             256       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 3, 3, 384)            24576     ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 3, 3, 384)            1536      ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 3, 3, 384)            0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 3, 3, 384)            3456      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 3, 3, 384)            1536      ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 3, 3, 384)            0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 3, 3, 64)             24576     ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 3, 3, 64)             256       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 3, 3, 64)             0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 3, 3, 384)            24576     ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 3, 3, 384)            1536      ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 3, 3, 384)            0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 3, 3, 384)            3456      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 3, 3, 384)            1536      ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 3, 3, 384)            0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 3, 3, 64)             24576     ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 3, 3, 64)             256       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 3, 3, 64)             0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 3, 3, 384)            24576     ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 3, 3, 384)            1536      ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 3, 3, 384)            0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 3, 3, 384)            3456      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 3, 3, 384)            1536      ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 3, 3, 384)            0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  block_9_project (Conv2D)    (None, 3, 3, 64)             24576     ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  block_9_project_BN (BatchN  (None, 3, 3, 64)             256       ['block_9_project[0][0]']
#  ormalization)
#
#  block_9_add (Add)           (None, 3, 3, 64)             0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)    (None, 3, 3, 384)            24576     ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 3, 3, 384)            1536      ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 3, 3, 384)            0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 3, 3, 384)            3456      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 3, 3, 384)            1536      ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 3, 3, 384)            0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 3, 3, 96)             36864     ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 3, 3, 96)             384       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 3, 3, 576)            55296     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 3, 3, 576)            2304      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 3, 3, 576)            0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 3, 3, 576)            5184      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 3, 3, 576)            2304      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  block_11_depthwise_relu (R  (None, 3, 3, 576)            0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_11_project (Conv2D)   (None, 3, 3, 96)             55296     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  block_11_project_BN (Batch  (None, 3, 3, 96)             384       ['block_11_project[0][0]']
#  Normalization)
#
#  block_11_add (Add)          (None, 3, 3, 96)             0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)    (None, 3, 3, 576)            55296     ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 3, 3, 576)            2304      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 3, 3, 576)            0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 3, 3, 576)            5184      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 3, 3, 576)            2304      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 3, 3, 576)            0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 3, 3, 96)             55296     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 3, 3, 96)             384       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 3, 3, 96)             0         ['block_11_add[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 3, 3, 576)            55296     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 3, 3, 576)            2304      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 3, 3, 576)            0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 5, 5, 576)            0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 2, 2, 576)            5184      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 2, 2, 576)            2304      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 2, 2, 576)            0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 2, 2, 160)            92160     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 2, 2, 160)            640       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 2, 2, 960)            153600    ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 2, 2, 960)            3840      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 2, 2, 960)            0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 2, 2, 960)            8640      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 2, 2, 960)            3840      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 2, 2, 960)            0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 2, 2, 160)            153600    ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 2, 2, 160)            640       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 2, 2, 160)            0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 2, 2, 960)            153600    ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 2, 2, 960)            3840      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 2, 2, 960)            0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 2, 2, 960)            8640      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 2, 2, 960)            3840      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 2, 2, 960)            0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 2, 2, 160)            153600    ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 2, 2, 160)            640       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 2, 2, 160)            0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)    (None, 2, 2, 960)            153600    ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchN  (None, 2, 2, 960)            3840      ['block_16_expand[0][0]']
#  ormalization)
#
#  block_16_expand_relu (ReLU  (None, 2, 2, 960)            0         ['block_16_expand_BN[0][0]']
#  )
#
#  block_16_depthwise (Depthw  (None, 2, 2, 960)            8640      ['block_16_expand_relu[0][0]']
#  iseConv2D)
#
#  block_16_depthwise_BN (Bat  (None, 2, 2, 960)            3840      ['block_16_depthwise[0][0]']
#  chNormalization)
#
#  block_16_depthwise_relu (R  (None, 2, 2, 960)            0         ['block_16_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_16_project (Conv2D)   (None, 2, 2, 320)            307200    ['block_16_depthwise_relu[0][0
#                                                                     ]']
#
#  block_16_project_BN (Batch  (None, 2, 2, 320)            1280      ['block_16_project[0][0]']
#  Normalization)
#
#  Conv_1 (Conv2D)             (None, 2, 2, 1280)           409600    ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalizat  (None, 2, 2, 1280)           5120      ['Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 2, 2, 1280)           0         ['Conv_1_bn[0][0]']
#
# ==================================================================================================
# Total params: 2257984 (8.61 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 2257984 (8.61 MB)
# __________________________________________________________________________________________________

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
prediction_layer = tf.keras.layers.Dense(10)

# %%
model = tf.keras.Sequential([
    base_model,
    global_average_layer,
    prediction_layer
])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Func  (None, 2, 2, 1280)        2257984
#  tional)
#
#  global_average_pooling2d_4  (None, 1280)              0
#   (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 10)                12810
#
# =================================================================
# Total params: 2270794 (8.66 MB)
# Trainable params: 12810 (50.04 KB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
base_learning_rate = 0.0001

model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=base_learning_rate), 
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Func  (None, 2, 2, 1280)        2257984
#  tional)
#
#  global_average_pooling2d_4  (None, 1280)              0
#   (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 10)                12810
#
# =================================================================
# Total params: 2270794 (8.66 MB)
# Trainable params: 12810 (50.04 KB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
initial_epochs = 10
validation_steps = 32

history = model.fit(train_X, train_label, epochs=initial_epochs, validation_data=(valid_X,valid_label))
acc = history.history['accuracy']
print(acc)
# Out:
# Epoch 1/10
# 225/225 [==============================] - 6s 18ms/step - loss: 0.3735 - accuracy: 0.3239 - val_loss: 0.2398 - val_accuracy: 0.5550
# Epoch 2/10
# 225/225 [==============================] - 4s 16ms/step - loss: 0.1952 - accuracy: 0.6733 - val_loss: 0.1763 - val_accuracy: 0.7000
# Epoch 3/10
# 225/225 [==============================] - 4s 16ms/step - loss: 0.1550 - accuracy: 0.7418 - val_loss: 0.1518 - val_accuracy: 0.7412
# Epoch 4/10
# 225/225 [==============================] - 4s 16ms/step - loss: 0.1368 - accuracy: 0.7657 - val_loss: 0.1386 - val_accuracy: 0.7600
# Epoch 5/10
# 225/225 [==============================] - 4s 16ms/step - loss: 0.1258 - accuracy: 0.7819 - val_loss: 0.1306 - val_accuracy: 0.7750
# Epoch 6/10
# 225/225 [==============================] - 4s 16ms/step - loss: 0.1183 - accuracy: 0.7933 - val_loss: 0.1247 - val_accuracy: 0.7788
# Epoch 7/10
# 225/225 [==============================] - 4s 16ms/step - loss: 0.1126 - accuracy: 0.8014 - val_loss: 0.1202 - val_accuracy: 0.7837
# Epoch 8/10
# 225/225 [==============================] - 4s 16ms/step - loss: 0.1080 - accuracy: 0.8100 - val_loss: 0.1168 - val_accuracy: 0.7875
# Epoch 9/10
# 225/225 [==============================] - 4s 16ms/step - loss: 0.1042 - accuracy: 0.8154 - val_loss: 0.1142 - val_accuracy: 0.7937
# Epoch 10/10
# 225/225 [==============================] - 4s 16ms/step - loss: 0.1011 - accuracy: 0.8215 - val_loss: 0.1118 - val_accuracy: 0.7975
# [0.323888897895813, 0.6733333468437195, 0.7418055534362793, 0.7656944394111633, 0.7819444537162781, 0.7933333516120911, 0.8013888597488403, 0.8100000023841858, 0.815416693687439, 0.8215277791023254]
