# %%
import pandas as pd

# %%
# file_name = 'fulltimeSU.csv'
file_name = 'USUnemployment.csv'

df = pd.read_csv('./data/' + file_name)

# %%
df.describe()
# Out:
#              Year        Jan        Feb        Mar        Apr        May  \
# count    72.00000  72.000000  72.000000  72.000000  72.000000  72.000000
# mean   1983.50000   5.734722   5.730556   5.737500   5.736111   5.731944
# std      20.92845   1.603970   1.628240   1.648169   1.681993   1.702842
# min    1948.00000   2.900000   2.600000   2.600000   2.700000   2.500000
# 25%    1965.75000   4.600000   4.600000   4.550000   4.575000   4.400000
# 50%    1983.50000   5.650000   5.500000   5.550000   5.500000   5.600000
# 75%    2001.25000   6.600000   6.625000   6.725000   6.925000   7.025000
# max    2019.00000  10.400000  10.400000  10.300000  10.200000  10.100000
#
#              Jun        Jul        Aug        Sep        Oct        Nov  \
# count  72.000000  72.000000  72.000000  72.000000  72.000000  72.000000
# mean    5.748611   5.740278   5.733333   5.718056   5.734722   5.726389
# std     1.683306   1.665868   1.653677   1.649356   1.662271   1.654017
# ...

# %%
df.head(5)
# Out:
#    Year  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# 0  1948  3.4  3.8  4.0  3.9  3.5  3.6  3.6  3.9  3.8  3.7  3.8  4.0
# 1  1949  4.3  4.7  5.0  5.3  6.1  6.2  6.7  6.8  6.6  7.9  6.4  6.6
# 2  1950  6.5  6.4  6.3  5.8  5.5  5.4  5.0  4.5  4.4  4.2  4.2  4.3
# 3  1951  3.7  3.4  3.4  3.1  3.0  3.2  3.1  3.1  3.3  3.5  3.5  3.1
# 4  1952  3.2  3.1  2.9  2.9  3.0  3.0  3.2  3.4  3.1  3.0  2.8  2.7

# %%
# TODO 1
#     1- To understand the ABOVE data better draw a heatmap aswell

# %%
# TODO 2
#     1- Convert this dataset to (YEAR-MONTH-01, YEAR, MONTH, COUNT)
#     2- Then draw the trned
#     3- Then create a model for the data with sklearn.linear_model.LinearRegression, choose a good X and Y obviously is COUNT
#     4- You may also show it in a simple nice UI as well

# %%
df['average'] = df.apply(lambda x: (x.Jan+x.Feb+x.Mar+x.Apr+x.May+x.Jun+x.Jul+x.Aug+x.Sep+x.Oct+x.Nov+x.Dec)/12, axis=1)

# %%
df.head()
# Out:
#    Year  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec   average
# 0  1948  3.4  3.8  4.0  3.9  3.5  3.6  3.6  3.9  3.8  3.7  3.8  4.0  3.750000
# 1  1949  4.3  4.7  5.0  5.3  6.1  6.2  6.7  6.8  6.6  7.9  6.4  6.6  6.050000
# 2  1950  6.5  6.4  6.3  5.8  5.5  5.4  5.0  4.5  4.4  4.2  4.2  4.3  5.208333
# 3  1951  3.7  3.4  3.4  3.1  3.0  3.2  3.1  3.1  3.3  3.5  3.5  3.1  3.283333
# 4  1952  3.2  3.1  2.9  2.9  3.0  3.0  3.2  3.4  3.1  3.0  2.8  2.7  3.025000

# %%
df.plot(x='Year', y='average', figsize=(15, 3), grid=True)
# Out:
# <Axes: xlabel='Year'>

# %%
# TODO 3
#     1- Run a clustering over years with 12 differnt months of data and find similar years
#     2- Do the same for just using the average of unemployment
#     3- Nicely show them on UI    
#     4- Write it so clean so that we can easily change the Algorrithm (K-MEANS, GAUSIAN MIXTURE, DISTRIBUTED CLUSTRINT, ...)
#     5- don't forget you should also SHOW CLUSTERS (YEAR, # of members) as well

# %%
# TODO 3
#     - find out which months usually have higher unemployement
